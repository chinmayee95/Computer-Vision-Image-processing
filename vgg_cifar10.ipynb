# %% [markdown]
# <a href="https://colab.research.google.com/github/chinmayee95/Computer-Vision-Image-processing/blob/master/vgg_cifar10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from __future__ import print_function
import keras
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from keras import optimizers
import numpy as np
from keras.layers.core import Lambda
from keras import backend as K
from keras import regularizers

class cifar10vgg:
    def __init__(self,train=True):
        self.num_classes = 10
        self.weight_decay = 0.0005
        self.x_shape = [32,32,3]

        self.model = self.build_model()
        if train:
            self.model = self.train(self.model)
        else:
            self.model.load_weights('cifar10vgg.h5')


    def build_model(self):
        # Build the network of vgg for 10 classes with massive dropout and weight decay as described in the paper.

        model = Sequential()
        weight_decay = self.weight_decay

        model.add(Conv2D(64, (3, 3), padding='same',
                         input_shape=self.x_shape,kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.3))

        model.add(Conv2D(64, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())

        model.add(MaxPooling2D(pool_size=(2, 2)))

        model.add(Conv2D(128, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.4))

        model.add(Conv2D(128, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())

        model.add(MaxPooling2D(pool_size=(2, 2)))

        model.add(Conv2D(256, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.4))

        model.add(Conv2D(256, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.4))

        model.add(Conv2D(256, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())

        model.add(MaxPooling2D(pool_size=(2, 2)))


        model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.4))

        model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.4))

        model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())

        model.add(MaxPooling2D(pool_size=(2, 2)))


        model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.4))

        model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.4))

        model.add(Conv2D(512, (3, 3), padding='same',kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())

        model.add(MaxPooling2D(pool_size=(2, 2)))
        model.add(Dropout(0.5))

        model.add(Flatten())
        model.add(Dense(512,kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())

        model.add(Dropout(0.5))
        model.add(Dense(self.num_classes))
        model.add(Activation('softmax'))
        return model


    def normalize(self,X_train,X_test):
        #this function normalize inputs for zero mean and unit variance
        # it is used when training a model.
        # Input: training set and test set
        # Output: normalized training set and test set according to the trianing set statistics.
        mean = np.mean(X_train,axis=(0,1,2,3))
        std = np.std(X_train, axis=(0, 1, 2, 3))
        X_train = (X_train-mean)/(std+1e-7)
        X_test = (X_test-mean)/(std+1e-7)
        return X_train, X_test

    def normalize_production(self,x):
        #this function is used to normalize instances in production according to saved training set statistics
        # Input: X - a training set
        # Output X - a normalized training set according to normalization constants.

        #these values produced during first training and are general for the standard cifar10 training set normalization
        mean = 120.707
        std = 64.15
        return (x-mean)/(std+1e-7)

    def predict(self,x,normalize=True,batch_size=50):
        if normalize:
            x = self.normalize_production(x)
        return self.model.predict(x,batch_size)

    def train(self,model):

        #training parameters
        batch_size = 64
        maxepoches = 100
        learning_rate = 0.001
        lr_decay = 1e-6
        lr_drop = 20
        # The data, shuffled and split between train and test sets:
        (x_train, y_train), (x_test, y_test) = cifar10.load_data()
        x_train = x_train.astype('float32')
        x_test = x_test.astype('float32')
        x_train, x_test = self.normalize(x_train, x_test)

        y_train = keras.utils.to_categorical(y_train, self.num_classes)
        y_test = keras.utils.to_categorical(y_test, self.num_classes)

        def lr_scheduler(epoch):
            return learning_rate * (0.5 ** (epoch // lr_drop))
        reduce_lr = keras.callbacks.LearningRateScheduler(lr_scheduler)

        #data augmentation
        datagen = ImageDataGenerator(
            featurewise_center=False,  # set input mean to 0 over the dataset
            samplewise_center=False,  # set each sample mean to 0
            featurewise_std_normalization=False,  # divide inputs by std of the dataset
            samplewise_std_normalization=False,  # divide each input by its std
            zca_whitening=False,  # apply ZCA whitening
            rotation_range=15,  # randomly rotate images in the range (degrees, 0 to 180)
            width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
            height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
            horizontal_flip=True,  # randomly flip images
            vertical_flip=False)  # randomly flip images
        # (std, mean, and principal components if ZCA whitening is applied).
        datagen.fit(x_train)



        #optimization details

        opt_adam = keras.optimizers.Adam(learning_rate=0.001, decay=0.0001, beta_1=0.9, beta_2=0.999, amsgrad=False)

        # lenet.compile(optimizer = opt_adam , loss = "categorical_crossentropy", metrics=["accuracy"])
        
        # sgd = optimizers.SGD(lr=learning_rate, decay=lr_decay, momentum=0.9, nesterov=True)
        model.compile(loss='categorical_crossentropy', optimizer=opt_adam,metrics=['accuracy'])


        # training process in a for loop with learning rate drop every 25 epoches.

        historytemp = model.fit_generator(datagen.flow(x_train, y_train,
                                         batch_size=batch_size),
                            steps_per_epoch=x_train.shape[0] // batch_size,
                            epochs=maxepoches,
                            validation_data=(x_test, y_test),callbacks=[reduce_lr],verbose=2)
        model.save_weights('cifar10vgg.h5')
        return model

if __name__ == '__main__':


    (x_train, y_train), (x_test, y_test) = cifar10.load_data()
    x_train = x_train.astype('float32')
    x_test = x_test.astype('float32')

    y_train = keras.utils.to_categorical(y_train, 10)
    y_test = keras.utils.to_categorical(y_test, 10)

    model = cifar10vgg()

    predicted_x = model.predict(x_test)
    residuals = np.argmax(predicted_x,1)!=np.argmax(y_test,1)

    loss = sum(residuals)/len(residuals)
    print("the validation 0/1 loss is: ",loss)
# Out:
# Epoch 1/100
#  - 55s - loss: 4.2817 - accuracy: 0.2627 - val_loss: 3.4432 - val_accuracy: 0.3725
# Epoch 2/100
#  - 50s - loss: 2.9621 - accuracy: 0.4435 - val_loss: 2.4297 - val_accuracy: 0.5268
# Epoch 3/100
#  - 50s - loss: 2.2520 - accuracy: 0.5352 - val_loss: 1.9945 - val_accuracy: 0.5741
# Epoch 4/100
#  - 50s - loss: 1.8715 - accuracy: 0.5986 - val_loss: 1.6419 - val_accuracy: 0.6577
# Epoch 5/100
#  - 50s - loss: 1.7117 - accuracy: 0.6342 - val_loss: 1.7093 - val_accuracy: 0.6356
# Epoch 6/100
#  - 50s - loss: 1.6534 - accuracy: 0.6562 - val_loss: 1.5727 - val_accuracy: 0.6948
# Epoch 7/100
#  - 50s - loss: 1.6136 - accuracy: 0.6820 - val_loss: 1.6155 - val_accuracy: 0.6730
# Epoch 8/100
#  - 49s - loss: 1.5819 - accuracy: 0.6992 - val_loss: 1.5273 - val_accuracy: 0.7134
# Epoch 9/100
#  - 49s - loss: 1.5596 - accuracy: 0.7082 - val_loss: 1.5000 - val_accuracy: 0.7367
# Epoch 10/100
#  - 49s - loss: 1.5250 - accuracy: 0.7247 - val_loss: 1.3835 - val_accuracy: 0.7723
# Epoch 11/100
#  - 50s - loss: 1.5021 - accuracy: 0.7343 - val_loss: 1.4250 - val_accuracy: 0.7510
# Epoch 12/100
#  - 50s - loss: 1.4547 - accuracy: 0.7458 - val_loss: 1.3972 - val_accuracy: 0.7595
# Epoch 13/100
#  - 50s - loss: 1.4271 - accuracy: 0.7537 - val_loss: 1.3332 - val_accuracy: 0.7907
# Epoch 14/100
#  - 49s - loss: 1.3864 - accuracy: 0.7631 - val_loss: 1.2644 - val_accuracy: 0.8051
# Epoch 15/100
#  - 49s - loss: 1.3737 - accuracy: 0.7713 - val_loss: 1.3475 - val_accuracy: 0.7660
# Epoch 16/100
#  - 50s - loss: 1.3325 - accuracy: 0.7756 - val_loss: 1.1799 - val_accuracy: 0.8165
# Epoch 17/100
#  - 49s - loss: 1.2971 - accuracy: 0.7840 - val_loss: 1.1312 - val_accuracy: 0.8237
# Epoch 18/100
#  - 49s - loss: 1.2638 - accuracy: 0.7901 - val_loss: 1.1003 - val_accuracy: 0.8362
# Epoch 19/100
#  - 50s - loss: 1.2466 - accuracy: 0.7930 - val_loss: 1.1569 - val_accuracy: 0.8157
# Epoch 20/100
#  - 50s - loss: 1.2169 - accuracy: 0.7986 - val_loss: 1.0492 - val_accuracy: 0.8450
# Epoch 21/100
#  - 50s - loss: 1.0555 - accuracy: 0.8308 - val_loss: 0.9100 - val_accuracy: 0.8657
# Epoch 22/100
#  - 49s - loss: 0.9768 - accuracy: 0.8415 - val_loss: 0.8845 - val_accuracy: 0.8600
# Epoch 23/100
#  - 49s - loss: 0.9380 - accuracy: 0.8433 - val_loss: 0.8568 - val_accuracy: 0.8623
# Epoch 24/100
#  - 49s - loss: 0.9079 - accuracy: 0.8479 - val_loss: 0.8415 - val_accuracy: 0.8635
# Epoch 25/100
#  - 49s - loss: 0.8837 - accuracy: 0.8502 - val_loss: 0.8152 - val_accuracy: 0.8690
# Epoch 26/100
#  - 49s - loss: 0.8613 - accuracy: 0.8542 - val_loss: 0.8060 - val_accuracy: 0.8725
# Epoch 27/100
#  - 49s - loss: 0.8415 - accuracy: 0.8576 - val_loss: 0.8234 - val_accuracy: 0.8626
# Epoch 28/100
#  - 49s - loss: 0.8157 - accuracy: 0.8620 - val_loss: 0.7557 - val_accuracy: 0.8806
# Epoch 29/100
#  - 49s - loss: 0.8024 - accuracy: 0.8635 - val_loss: 0.7240 - val_accuracy: 0.8846
# Epoch 30/100
#  - 50s - loss: 0.7896 - accuracy: 0.8668 - val_loss: 0.7527 - val_accuracy: 0.8772
# Epoch 31/100
#  - 50s - loss: 0.7810 - accuracy: 0.8672 - val_loss: 0.7293 - val_accuracy: 0.8816
# Epoch 32/100
#  - 50s - loss: 0.7658 - accuracy: 0.8707 - val_loss: 0.6954 - val_accuracy: 0.8915
# Epoch 33/100
#  - 50s - loss: 0.7506 - accuracy: 0.8739 - val_loss: 0.7157 - val_accuracy: 0.8862
# Epoch 34/100
#  - 50s - loss: 0.7367 - accuracy: 0.8774 - val_loss: 0.7033 - val_accuracy: 0.8841
# Epoch 35/100
#  - 50s - loss: 0.7311 - accuracy: 0.8751 - val_loss: 0.6936 - val_accuracy: 0.8860
# Epoch 36/100
#  - 50s - loss: 0.7163 - accuracy: 0.8790 - val_loss: 0.6506 - val_accuracy: 0.8971
# Epoch 37/100
#  - 50s - loss: 0.7088 - accuracy: 0.8800 - val_loss: 0.6497 - val_accuracy: 0.8987
# Epoch 38/100
#  - 50s - loss: 0.6978 - accuracy: 0.8822 - val_loss: 0.6697 - val_accuracy: 0.8940
# Epoch 39/100
#  - 50s - loss: 0.6891 - accuracy: 0.8853 - val_loss: 0.6552 - val_accuracy: 0.8946
# Epoch 40/100
#  - 50s - loss: 0.6820 - accuracy: 0.8855 - val_loss: 0.6520 - val_accuracy: 0.8952
# Epoch 41/100
#  - 50s - loss: 0.6328 - accuracy: 0.8968 - val_loss: 0.5993 - val_accuracy: 0.9045
# Epoch 42/100
#  - 50s - loss: 0.6066 - accuracy: 0.9009 - val_loss: 0.5993 - val_accuracy: 0.9024
# Epoch 43/100
#  - 49s - loss: 0.5876 - accuracy: 0.9048 - val_loss: 0.5900 - val_accuracy: 0.9043
# Epoch 44/100
#  - 50s - loss: 0.5801 - accuracy: 0.9051 - val_loss: 0.5768 - val_accuracy: 0.9077
# Epoch 45/100
#  - 49s - loss: 0.5712 - accuracy: 0.9075 - val_loss: 0.5666 - val_accuracy: 0.9107
# Epoch 46/100
#  - 49s - loss: 0.5631 - accuracy: 0.9075 - val_loss: 0.5702 - val_accuracy: 0.9068
# Epoch 47/100
#  - 49s - loss: 0.5552 - accuracy: 0.9073 - val_loss: 0.5523 - val_accuracy: 0.9110
# Epoch 48/100
#  - 49s - loss: 0.5494 - accuracy: 0.9094 - val_loss: 0.5463 - val_accuracy: 0.9125
# Epoch 49/100
#  - 49s - loss: 0.5384 - accuracy: 0.9123 - val_loss: 0.5580 - val_accuracy: 0.9080
# Epoch 50/100
#  - 49s - loss: 0.5319 - accuracy: 0.9116 - val_loss: 0.5457 - val_accuracy: 0.9107
# Epoch 51/100
#  - 49s - loss: 0.5252 - accuracy: 0.9141 - val_loss: 0.5348 - val_accuracy: 0.9156
# Epoch 52/100
#  - 49s - loss: 0.5262 - accuracy: 0.9134 - val_loss: 0.5494 - val_accuracy: 0.9083
# Epoch 53/100
#  - 49s - loss: 0.5151 - accuracy: 0.9152 - val_loss: 0.5439 - val_accuracy: 0.9088
# Epoch 54/100
#  - 49s - loss: 0.5077 - accuracy: 0.9181 - val_loss: 0.5308 - val_accuracy: 0.9119
# Epoch 55/100
#  - 49s - loss: 0.5092 - accuracy: 0.9166 - val_loss: 0.5314 - val_accuracy: 0.9118
# Epoch 56/100
#  - 49s - loss: 0.4989 - accuracy: 0.9185 - val_loss: 0.5170 - val_accuracy: 0.9162
# Epoch 57/100
#  - 49s - loss: 0.4925 - accuracy: 0.9196 - val_loss: 0.5154 - val_accuracy: 0.9172
# Epoch 58/100
#  - 49s - loss: 0.4894 - accuracy: 0.9203 - val_loss: 0.5304 - val_accuracy: 0.9119
# Epoch 59/100
#  - 49s - loss: 0.4882 - accuracy: 0.9204 - val_loss: 0.5188 - val_accuracy: 0.9150
# Epoch 60/100
#  - 49s - loss: 0.4808 - accuracy: 0.9210 - val_loss: 0.5218 - val_accuracy: 0.9128
# Epoch 61/100
#  - 49s - loss: 0.4637 - accuracy: 0.9260 - val_loss: 0.5034 - val_accuracy: 0.9157
# Epoch 62/100
#  - 49s - loss: 0.4558 - accuracy: 0.9268 - val_loss: 0.5062 - val_accuracy: 0.9177
# Epoch 63/100
#  - 49s - loss: 0.4460 - accuracy: 0.9295 - val_loss: 0.5007 - val_accuracy: 0.9173
# Epoch 64/100
#  - 50s - loss: 0.4473 - accuracy: 0.9296 - val_loss: 0.4966 - val_accuracy: 0.9180
# Epoch 65/100
#  - 49s - loss: 0.4395 - accuracy: 0.9318 - val_loss: 0.5001 - val_accuracy: 0.9162
# Epoch 66/100
#  - 48s - loss: 0.4380 - accuracy: 0.9318 - val_loss: 0.4876 - val_accuracy: 0.9195
# Epoch 67/100
#  - 48s - loss: 0.4303 - accuracy: 0.9329 - val_loss: 0.4885 - val_accuracy: 0.9185
# Epoch 68/100
#  - 48s - loss: 0.4259 - accuracy: 0.9353 - val_loss: 0.4882 - val_accuracy: 0.9198
# Epoch 69/100
#  - 48s - loss: 0.4278 - accuracy: 0.9333 - val_loss: 0.4816 - val_accuracy: 0.9218
# Epoch 70/100
#  - 48s - loss: 0.4251 - accuracy: 0.9331 - val_loss: 0.4792 - val_accuracy: 0.9212
# Epoch 71/100
#  - 48s - loss: 0.4259 - accuracy: 0.9328 - val_loss: 0.4808 - val_accuracy: 0.9192
# Epoch 72/100
#  - 48s - loss: 0.4160 - accuracy: 0.9360 - val_loss: 0.4732 - val_accuracy: 0.9231
# Epoch 73/100
#  - 48s - loss: 0.4143 - accuracy: 0.9357 - val_loss: 0.4753 - val_accuracy: 0.9199
# Epoch 74/100
#  - 48s - loss: 0.4154 - accuracy: 0.9348 - val_loss: 0.4835 - val_accuracy: 0.9190
# Epoch 75/100
#  - 48s - loss: 0.4066 - accuracy: 0.9367 - val_loss: 0.4752 - val_accuracy: 0.9214
# Epoch 76/100
#  - 48s - loss: 0.4036 - accuracy: 0.9384 - val_loss: 0.4777 - val_accuracy: 0.9202
# Epoch 77/100
#  - 49s - loss: 0.4051 - accuracy: 0.9368 - val_loss: 0.4726 - val_accuracy: 0.9215
# Epoch 78/100
#  - 48s - loss: 0.4008 - accuracy: 0.9393 - val_loss: 0.4743 - val_accuracy: 0.9224
# Epoch 79/100
#  - 48s - loss: 0.4003 - accuracy: 0.9375 - val_loss: 0.4742 - val_accuracy: 0.9210
# Epoch 80/100
#  - 48s - loss: 0.3973 - accuracy: 0.9383 - val_loss: 0.4736 - val_accuracy: 0.9213
# Epoch 81/100
#  - 48s - loss: 0.3884 - accuracy: 0.9404 - val_loss: 0.4680 - val_accuracy: 0.9217
# Epoch 82/100
#  - 48s - loss: 0.3879 - accuracy: 0.9410 - val_loss: 0.4646 - val_accuracy: 0.9220
# Epoch 83/100
#  - 48s - loss: 0.3849 - accuracy: 0.9422 - val_loss: 0.4673 - val_accuracy: 0.9211
# Epoch 84/100
#  - 48s - loss: 0.3793 - accuracy: 0.9429 - val_loss: 0.4675 - val_accuracy: 0.9208
# Epoch 85/100
#  - 48s - loss: 0.3858 - accuracy: 0.9406 - val_loss: 0.4666 - val_accuracy: 0.9214
# Epoch 86/100
#  - 47s - loss: 0.3815 - accuracy: 0.9423 - val_loss: 0.4586 - val_accuracy: 0.9225
# Epoch 87/100
#  - 47s - loss: 0.3823 - accuracy: 0.9426 - val_loss: 0.4684 - val_accuracy: 0.9216
# Epoch 88/100
#  - 47s - loss: 0.3738 - accuracy: 0.9426 - val_loss: 0.4711 - val_accuracy: 0.9205
# Epoch 89/100
#  - 47s - loss: 0.3771 - accuracy: 0.9424 - val_loss: 0.4602 - val_accuracy: 0.9224
# Epoch 90/100
#  - 47s - loss: 0.3746 - accuracy: 0.9434 - val_loss: 0.4615 - val_accuracy: 0.9237
# Epoch 91/100
#  - 48s - loss: 0.3727 - accuracy: 0.9443 - val_loss: 0.4611 - val_accuracy: 0.9240
# Epoch 92/100
#  - 48s - loss: 0.3681 - accuracy: 0.9453 - val_loss: 0.4692 - val_accuracy: 0.9213
# Epoch 93/100
#  - 48s - loss: 0.3711 - accuracy: 0.9444 - val_loss: 0.4625 - val_accuracy: 0.9221
# Epoch 94/100
#  - 48s - loss: 0.3708 - accuracy: 0.9442 - val_loss: 0.4598 - val_accuracy: 0.9227
# Epoch 95/100
#  - 48s - loss: 0.3690 - accuracy: 0.9445 - val_loss: 0.4605 - val_accuracy: 0.9232
# Epoch 96/100
#  - 48s - loss: 0.3656 - accuracy: 0.9452 - val_loss: 0.4583 - val_accuracy: 0.9230
# Epoch 97/100
#  - 48s - loss: 0.3674 - accuracy: 0.9448 - val_loss: 0.4628 - val_accuracy: 0.9224
# Epoch 98/100
#  - 48s - loss: 0.3679 - accuracy: 0.9438 - val_loss: 0.4581 - val_accuracy: 0.9233
# Epoch 99/100
#  - 48s - loss: 0.3632 - accuracy: 0.9455 - val_loss: 0.4548 - val_accuracy: 0.9237
# Epoch 100/100
#  - 48s - loss: 0.3633 - accuracy: 0.9453 - val_loss: 0.4580 - val_accuracy: 0.9239
# the validation 0/1 loss is:  0.0761
