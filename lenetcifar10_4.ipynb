# %% [markdown]
# <a href="https://colab.research.google.com/github/chinmayee95/Computer-Vision-Image-processing/blob/master/lenetcifar10_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras
from keras.models import Sequential
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import LeakyReLU
from keras.datasets import cifar10
from keras import regularizers
from keras.callbacks import LearningRateScheduler
import numpy as np
 
def lr_schedule(epoch):
    lrate = 0.001
    if epoch > 55:
        lrate = 0.0001
    if epoch > 75:
        lrate = 0.0001
    return lrate
 
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
 
#z-score
mean = np.mean(x_train,axis=(0,1,2,3))
std = np.std(x_train,axis=(0,1,2,3))
x_train = (x_train-mean)/(std+1e-7)
x_test = (x_test-mean)/(std+1e-7)
 
num_classes = 10
y_train = np_utils.to_categorical(y_train,num_classes)
y_test = np_utils.to_categorical(y_test,num_classes)
 
weight_decay = 1e-3
lenet = Sequential()
lenet.add(Conv2D(32, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay), input_shape=x_train.shape[1:]))
lenet.add(Activation('relu'))
lenet.add(BatchNormalization())
lenet.add(Conv2D(32, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
lenet.add(Activation('relu'))
lenet.add(BatchNormalization())
lenet.add(MaxPooling2D(pool_size=(2,2)))
# lenet.add(Dropout(0.5))
 
lenet.add(Conv2D(64, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
# lenet.add(Activation('relu'))
lenet.add(LeakyReLU(alpha=0.01))

lenet.add(BatchNormalization())
lenet.add(Conv2D(64, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
lenet.add(Activation('elu'))
# lenet.add(LeakyReLU(alpha=0.01))

lenet.add(BatchNormalization())
lenet.add(MaxPooling2D(pool_size=(2,2)))
# lenet.add(Dropout(0.5))
 
lenet.add(Conv2D(128, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
lenet.add(Activation('elu'))
# lenet.add(LeakyReLU(alpha=0.01))

lenet.add(BatchNormalization())
lenet.add(Conv2D(128, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
lenet.add(Activation('elu'))
# lenet.add(LeakyReLU(alpha=0.01))

lenet.add(BatchNormalization())
lenet.add(MaxPooling2D(pool_size=(2,2)))
# lenet.add(Dropout(0.5))
 
lenet.add(Flatten())
lenet.add(Dense(1024))
lenet.add(LeakyReLU(alpha=0.01))
lenet.add(Dropout(0.5))

lenet.add(Dense(512))
lenet.add(LeakyReLU(alpha=0.01))
lenet.add(Dropout(0.5))
lenet.add(Dense(256))
lenet.add(LeakyReLU(alpha=0.01))
lenet.add(Dropout(0.5))

lenet.add(Dense(128))
lenet.add(LeakyReLU(alpha=0.01))
lenet.add(Dropout(0.4))
lenet.add(Dense(64))
lenet.add(LeakyReLU(alpha=0.01))
lenet.add(Dropout(0.3))
lenet.add(Dense(num_classes, activation='softmax'))

lenet.summary()
 
#data augmentation
datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=0,  # randomly rotate images in the range (degrees, 0 to 180)
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=True,  # randomly flip images
        vertical_flip=False)  # randomly flip images
# ImageDataGenerator(
#     rotation_range=15,
#     width_shift_range=0.1,
#     height_shift_range=0.1,
#     horizontal_flip=True,
#     )
datagen.fit(x_train)
 
#training
batch_size = 64
opt_adam = keras.optimizers.Adam(learning_rate=0.001, decay=0.0001, beta_1=0.9, beta_2=0.999, amsgrad=False)

lenet.compile(optimizer = opt_adam , loss = "categorical_crossentropy", metrics=["accuracy"])
 
# opt_rms = keras.optimizers.rmsprop(lr=0.001,decay=1e-6)
# lenet.compile(loss='categorical_crossentropy', optimizer=opt_rms, metrics=['accuracy'])
lenet.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),\
                    steps_per_epoch=x_train.shape[0] // batch_size,epochs=100,\
                    verbose=1,validation_data=(x_test,y_test),callbacks=[LearningRateScheduler(lr_schedule)])
#save to disk
lenet_json = lenet.to_json()
with open('lenet.json', 'w') as json_file:
    json_file.write(lenet_json)
lenet.save_weights('lenet.h5') 
 
#testing
scores = lenet.evaluate(x_test, y_test, batch_size=128, verbose=1)
print('\nTest result: %.3f loss: %.3f' % (scores[1]*100,scores[0]))
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_7 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# activation_6 (Activation)    (None, 32, 32, 32)        0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# activation_7 (Activation)    (None, 32, 32, 32)        0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 16, 16, 64)        0
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 16, 16, 64)        36928
# _________________________________________________________________
# activation_8 (Activation)    (None, 16, 16, 64)        0
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 16, 16, 64)        256
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 8, 8, 128)         73856
# _________________________________________________________________
# activation_9 (Activation)    (None, 8, 8, 128)         0
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 8, 8, 128)         512
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 8, 8, 128)         147584
# _________________________________________________________________
# activation_10 (Activation)   (None, 8, 8, 128)         0
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 8, 8, 128)         512
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 1024)              0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 512)               524800
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 512)               0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 256)               131328
# _________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)   (None, 256)               0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 128)               32896
# _________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 64)                8256
# _________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)   (None, 64)                0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_12 (Dense)             (None, 10)                650
# =================================================================
# Total params: 3,084,906
# Trainable params: 3,084,010
# Non-trainable params: 896
# _________________________________________________________________
# Epoch 1
100
# 781/781 [==============================] - 26s 33ms/step - loss: 0.4827 - accuracy: 0.9028 - val_loss: 0.5632 - val_accuracy: 0.8757
# Epoch 55/100
# 781/781 [==============================] - 26s 33ms/step - loss: 0.4741 - accuracy: 0.9063 - val_loss: 0.5992 - val_accuracy: 0.8675
# Epoch 56/100
# 781/781 [==============================] - 26s 33ms/step - loss: 0.4676 - accuracy: 0.9081 - val_loss: 0.5737 - val_accuracy: 0.8787
# Epoch 57/100
# 781/781 [==============================] - 26s 33ms/step - loss: 0.4224 - accuracy: 0.9211 - val_loss: 0.5238 - val_accuracy: 0.8896
# Epoch 58/100
# 781/781 [==============================] - 26s 33ms/step - loss: 0.4110 - accuracy: 0.9230 - val_loss: 0.5219 - val_accuracy: 0.8907
# Epoch 59/100
# 781/781 [==============================] - 26s 33ms/step - loss: 0.3992 - accuracy: 0.9282 - val_loss: 0.5189 - val_accuracy: 0.8921
# Epoch 60/100
# 781/781 [==============================] - 26s 33ms/step - loss: 0.3928 - accuracy: 0.9289 - val_loss: 0.5255 - val_accuracy: 0.8890
# Epoch 61/100
# 781/781 [==============================] - 26s 33ms/step - loss: 0.3904 - accuracy: 0.9294 - val_loss: 0.5106 - val_accuracy: 0.8919
# Epoch 62/100
# 781/781 [==============================] - 26s 33ms/step - loss: 0.3836 - accuracy: 0.9322 - val_loss: 0.5082 - val_accuracy: 0.8947
# Epoch 63/100
# 781/781 [==============================] - 26s 33ms/step - loss: 0.3851 - accuracy: 0.9301 - val_loss: 0.5074 - val_accuracy: 0.8962
# Epoch 64/100
# 781/781 [==============================] - 26s 33ms/step - loss: 0.3754 - accuracy: 0.9338 - val_loss: 0.5058 - val_accuracy: 0.8972
# Epoch 65/100
# 781/781 [==============================] - 26s 33ms/step - loss: 0.3748 - accuracy: 0.9331 - val_loss: 0.4994 - val_accuracy: 0.8986
# Epoch 66/100
# 781/781 [==============================] - 26s 33ms/step - loss: 0.3713 - accuracy: 0.9335 - val_loss: 0.5085 - val_accuracy: 0.8962
# Epoch 67/100
# 781/781 [==============================] - 26s 33ms/step - loss: 0.3692 - accuracy: 0.9349 - val_loss: 0.4977 - val_accuracy: 0.8994
# Epoch 68/100
# 781/781 [==============================] - 26s 33ms/step - loss: 0.3695 - accuracy: 0.9343 - val_loss: 0.5030 - val_accuracy: 0.8997
# Epoch 69/100
# 781/781 [==============================] - 26s 33ms/step - loss: 0.3684 - accuracy: 0.9350 - val_loss: 0.5002 - val_accuracy: 0.8985
# Epoch 70/100
# 781/781 [==============================] - 26s 33ms/step - loss: 0.3582 - accuracy: 0.9375 - val_loss: 0.5041 - val_accuracy: 0.8994
# Epoch 71/100
# 781/781 [==============================] - 26s 33ms/step - loss: 0.3598 - accuracy: 0.9355 - val_loss: 0.5066 - val_accuracy: 0.8981
# Epoch 72/100
# 781/781 [==============================] - 26s 33ms/step - loss: 0.3604 - accuracy: 0.9361 - val_loss: 0.5005 - val_accuracy: 0.8988
# Epoch 73/100
# 781/781 [==============================] - 26s 33ms/step - loss: 0.3576 - accuracy: 0.9373 - val_loss: 0.5026 - val_accuracy: 0.9006
# Epoch 74/100
# 781/781 [==============================] - 26s 33ms/step - loss: 0.3561 - accuracy: 0.9376 - val_loss: 0.5075 - val_accuracy: 0.8987
# Epoch 75/100
# 781/781 [==============================] - 26s 33ms/step - loss: 0.3511 - accuracy: 0.9390 - val_loss: 0.5074 - val_accuracy: 0.8986
# Epoch 76/100
# 781/781 [==============================] - 26s 33ms/step - loss: 0.3478 - accuracy: 0.9391 - val_loss: 0.5004 - val_accuracy: 0.8992
# Epoch 77/100
# 781/781 [==============================] - 26s 33ms/step - loss: 0.3464 - accuracy: 0.9391 - val_loss: 0.5023 - val_accuracy: 0.8993
# Epoch 78/100
# 781/781 [==============================] - 26s 33ms/step - loss: 0.3500 - accuracy: 0.9380 - val_loss: 0.4915 - val_accuracy: 0.9019
# Epoch 79/100
# 781/781 [==============================] - 25s 33ms/step - loss: 0.3430 - accuracy: 0.9413 - val_loss: 0.4988 - val_accuracy: 0.9003
# Epoch 80/100
# 781/781 [==============================] - 26s 33ms/step - loss: 0.3467 - accuracy: 0.9400 - val_loss: 0.4964 - val_accuracy: 0.8998
# Epoch 81/100
# 781/781 [==============================] - 26s 33ms/step - loss: 0.3418 - accuracy: 0.9393 - val_loss: 0.4946 - val_accuracy: 0.9008
# Epoch 82/100
# 781/781 [==============================] - 26s 33ms/step - loss: 0.3431 - accuracy: 0.9401 - val_loss: 0.5063 - val_accuracy: 0.8999
# Epoch 83/100
# 781/781 [==============================] - 26s 33ms/step - loss: 0.3335 - accuracy: 0.9432 - val_loss: 0.5003 - val_accuracy: 0.8997
# Epoch 84/100
# 781/781 [==============================] - 26s 33ms/step - loss: 0.3406 - accuracy: 0.9406 - val_loss: 0.4932 - val_accuracy: 0.9023
# Epoch 85/100
# 781/781 [==============================] - 26s 33ms/step - loss: 0.3357 - accuracy: 0.9417 - val_loss: 0.4950 - val_accuracy: 0.9014
# Epoch 86/100
# 781/781 [==============================] - 26s 33ms/step - loss: 0.3356 - accuracy: 0.9413 - val_loss: 0.4952 - val_accuracy: 0.9010
# Epoch 87/100
# 781/781 [==============================] - 26s 33ms/step - loss: 0.3356 - accuracy: 0.9408 - val_loss: 0.4943 - val_accuracy: 0.9012
# Epoch 88/100
# 781/781 [==============================] - 25s 33ms/step - loss: 0.3319 - accuracy: 0.9426 - val_loss: 0.4974 - val_accuracy: 0.9005
# Epoch 89/100
# 781/781 [==============================] - 26s 33ms/step - loss: 0.3314 - accuracy: 0.9435 - val_loss: 0.4938 - val_accuracy: 0.9018
# Epoch 90/100
# 781/781 [==============================] - 26s 33ms/step - loss: 0.3319 - accuracy: 0.9435 - val_loss: 0.4919 - val_accuracy: 0.9014
# Epoch 91/100
# 781/781 [==============================] - 25s 33ms/step - loss: 0.3250 - accuracy: 0.9435 - val_loss: 0.4985 - val_accuracy: 0.8990
# Epoch 92/100
# 781/781 [==============================] - 26s 33ms/step - loss: 0.3249 - accuracy: 0.9441 - val_loss: 0.4942 - val_accuracy: 0.8985
# Epoch 93/100
# 781/781 [==============================] - 26s 33ms/step - loss: 0.3273 - accuracy: 0.9436 - val_loss: 0.4935 - val_accuracy: 0.9011
# Epoch 94/100
# 781/781 [==============================] - 26s 33ms/step - loss: 0.3220 - accuracy: 0.9450 - val_loss: 0.4930 - val_accuracy: 0.9008
# Epoch 95/100
# 781/781 [==============================] - 25s 33ms/step - loss: 0.3220 - accuracy: 0.9447 - val_loss: 0.4926 - val_accuracy: 0.9019
# Epoch 96/100
# 781/781 [==============================] - 26s 33ms/step - loss: 0.3203 - accuracy: 0.9454 - val_loss: 0.4967 - val_accuracy: 0.9009
# Epoch 97/100
# 781/781 [==============================] - 25s 33ms/step - loss: 0.3196 - accuracy: 0.9459 - val_loss: 0.4929 - val_accuracy: 0.9030
# Epoch 98/100
# 781/781 [==============================] - 25s 33ms/step - loss: 0.3190 - accuracy: 0.9437 - val_loss: 0.4987 - val_accuracy: 0.9012
# Epoch 99/100
# 781/781 [==============================] - 26s 33ms/step - loss: 0.3180 - accuracy: 0.9456 - val_loss: 0.4993 - val_accuracy: 0.9018
# Epoch 100/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.3194 - accuracy: 0.9453 - val_loss: 0.5028 - val_accuracy: 0.9006
# 10000/10000 [==============================] - 1s 67us/step
#
# Test result: 90.060 loss: 0.503

# %%
scores = le_net.evaluate(data_test, label_test, verbose=1)

print('Test loss:', scores[0])
print('Test accuracy:', scores[1])

# %%
import matplotlib.pyplot as plt

lenet_summary = lenet_fit.history

loss_values = lenet_summary['loss']
val_loss_values = lenet_summary['val_loss']
epochs = range(1, len(loss_values) + 1)

line1 = plt.plot(epochs, val_loss_values, label='Test Loss')
line2 = plt.plot(epochs, loss_values, label='Training Loss')
plt.setp(line1, linewidth=2.0, marker = '+', markersize=10.0)
plt.setp(line2, linewidth=2.0, marker = '4', markersize=10.0)
plt.xlabel('Epochs') 
plt.ylabel('Loss')
plt.grid(True)
plt.legend()
plt.show()

# %%
# Plotting our accuracy charts
import matplotlib.pyplot as plt

lenet_summary = lenet_fit.history

acc_values = lenet_summary['accuracy']
val_acc_values = lenet_summary['val_accuracy']
epochs = range(1, len(loss_values) + 1)

line1 = plt.plot(epochs, val_acc_values, label='Test Accuracy')
line2 = plt.plot(epochs, acc_values, label='Training Accuracy')
plt.setp(line1, linewidth=2.0, marker = '+', markersize=10.0)
plt.setp(line2, linewidth=2.0, marker = '4', markersize=10.0)
plt.xlabel('Epochs') 
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()
plt.show()
